# %% [markdown]
# # 01 Data Preprocessing
# Schema detection, target detection, missingness review, and preprocessing setup.

# %%
import sys
sys.path.append('..')
from src.preprocessing import read_dataset, detect_target, infer_schema
from src.feature_engineering import add_supply_chain_features
df = read_dataset('../data/raw/DataCoSupplyChainDataset.csv')
df = add_supply_chain_features(df)
schema = infer_schema(df)
schema
