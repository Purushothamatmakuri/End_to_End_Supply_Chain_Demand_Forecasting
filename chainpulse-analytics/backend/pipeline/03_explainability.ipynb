# %% [markdown]
# # 03 Explainability
# Generate SHAP artifacts for stakeholder-readable model interpretation.

# %%
import sys
sys.path.append('..')
from src.explainability import generate_shap_artifacts
generate_shap_artifacts(sample_size=1000)
