# %% [markdown]
# # 04 Fairness Review
# Assess group-level disparities across real operational segments.

# %%
import sys
sys.path.append('..')
from src.fairness_review import run_fairness_review
fairness = run_fairness_review(sample_size=20000)
fairness.head()
