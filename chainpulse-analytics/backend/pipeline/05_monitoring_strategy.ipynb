# %% [markdown]
# # 05 Monitoring Strategy
# Prediction drift and retraining-trigger logic.

# %%
import sys
sys.path.append('..')
import pandas as pd
from src.monitoring import prediction_drift, DRIFT_THRESHOLDS
prediction_drift(pd.Series([0, 1, 1, 0]), pd.Series([1, 1, 1, 0])), DRIFT_THRESHOLDS
