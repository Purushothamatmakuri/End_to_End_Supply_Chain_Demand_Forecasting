# %% [markdown]
# # 02 Model Training
# Train baseline, Random Forest, XGBoost, and MLP models.

# %%
import sys
sys.path.append('..')
from src.model_training import train_all
results = train_all('../data/raw/DataCoSupplyChainDataset.csv', sample_size=30000)
results['models'].keys()
